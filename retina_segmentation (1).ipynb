# %%
# !git clone -b  optimization/data-loader https://github.com/hkphimanshukumar321/retina_segmentation.git
# Out:
# Cloning into 'retina_segmentation'...
# remote: Enumerating objects: 1370, done.
# remote: Counting objects: 100% (34/34), done.
# remote: Compressing objects: 100% (23/23), done.
# remote: Total 1370 (delta 13), reused 29 (delta 11), pack-reused 1336 (from 2)
# Receiving objects: 100% (1370/1370), 221.92 MiB | 38.86 MiB/s, done.
# Resolving deltas: 100% (456/456), done.
# Updating files: 100% (1628/1628), done.

# %%
# !pip install -r requirements.txt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 43.9 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5/5 [segmentation-models]ficientnet]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torch-tensorrt 2.2.0a0 requires torch<2.4.0,>=2.1.0.dev, but you have torch 2.9.1 which is incompatible.
# torchtext 0.17.0a0 requires torch==2.2.0a0+81ea7a4, but you have torch 2.9.1 which is incompatible.
# ...
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python -m pip install --upgrade pip

# %%
# !python -m pip install --upgrade pip
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...

# %%
cd /home/abhays/retina_segmentation/segmentation/experiments/
# Out:
# /home/abhays/retina_segmentation/segmentation/experiments

# %%
# !pip install numpy==1.26.4
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...

# %%
# !python pilot_test.py
# Out:
# 2026-02-21 22:46:21.622228: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2026-02-21 22:46:21.622277: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2026-02-21 22:46:21.623955: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2026-02-21 22:46:21.631977: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
#
# ...
#   PILOT TEST — Ghost‑CAS‑UNet
# ...

# %%
# !python run.py
# Out:
# python: can't open file '/home/abhays/retina_segmentation/segmentation/experiments/run.py': [Errno 2] No such file or directory

# %%
# !python run.py --ablation
# Out:
# python: can't open file '/home/abhays/retina_segmentation/segmentation/experiments/run.py': [Errno 2] No such file or directory

# %%
pip install segmentation-models
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !python run.py --baselines
# Out:
# python: can't open file '/home/abhays/retina_segmentation/segmentation/experiments/run.py': [Errno 2] No such file or directory

# %%
# !python analysis
# Out:
# python: can't open file '/home/abhays/retina_segmentation/segmentation/experiments/analysis': [Errno 2] No such file or directory

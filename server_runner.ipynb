# %% [markdown]
# # 🚁 Omni Workbench - Server Runner
#
# **Copyright (c) 2026 Himanshu Kumar, IIT Bhubaneswar**
# Email: hkphimanshukumar321@gmail.com
#
# Use this notebook to run experiments on Colab, Kaggle, or remote servers.

# %% [markdown]
# ## 1. Setup & Clone
# Replace input the URL to your repository below.

# %%
# TODO: Replace with your actual repository URL
REPO_URL = "https://github.com/hkphimanshukumar321/uav_detection_rfbspectra.git"

# !git clone {REPO_URL}
# %cd uav_detection_rfbspectra/template
# !pip install -r requirements.txt

# %% [markdown]
# ## 2. Validation (Audit)
# Run smoke tests to verify the environment. Generates `AUDIT_REPORT.md`.

# %%
# !python classification/tests/test_smoke.py

# %% [markdown]
# ## 3. Quick Run
# Run a fast verification of the training pipeline (1 epoch, minimal data).

# %%
# Choose your task: classification, segmentation, or detection
TASK = "classification"

# !python {TASK}/run.py --quick

# %% [markdown]
# ## 4. Full Experiment
# Run the full configured experiment pipeline.

# %%
# !python {TASK}/run.py
